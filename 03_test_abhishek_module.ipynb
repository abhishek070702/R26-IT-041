# %%
import sys
from pathlib import Path

project_path = Path(r"C:\Users\Abhishek\Desktop\Document_Type_Project_Final")

if str(project_path) not in sys.path:
    sys.path.append(str(project_path))

print("Project path added:", project_path)
# Out:
# Project path added: C:\Users\Abhishek\Desktop\Document_Type_Project_Final

# %%
from backend.abhishek_module.pipeline import analyze_page

print("analyze_page imported successfully")
# Out:
# Document Identification model loaded successfully
# Project folder: C:\Users\Abhishek\Desktop\Document_Type_Project_Final
# Model path: C:\Users\Abhishek\Desktop\Document_Type_Project_Final\model\best_document_model_finetuned.pth
# Using device: cuda
# Classes: ['Magazine', 'Newspaper', 'Novel', 'Printed_Letter', 'Report']
# Using CPU. Note: This module is much faster with a GPU.
# EasyOCR title reader loaded successfully
# EasyOCR GPU: False
# analyze_page imported successfully

# %%
image_path = r"C:\Users\Abhishek\Desktop\Document_Type_Project_Final\test_images\ceylon_today.jpg"

result = analyze_page(image_path)
result
# Out:
# {'document_type': 'Unknown',
#  'confidence': 0.0,
#  'title': '',
#  'image_descriptions': [],
#  'status': 'failed',
#  'warnings': ['Document identification failed']}
